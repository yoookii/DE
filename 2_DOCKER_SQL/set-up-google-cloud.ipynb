# %% [markdown]
# ### google cloud platform
# ## compute engine
# 1. **settings -> metadata**
#    * add ssh keys
# 2. **vm instances**
#    * operations -> create an instance
#    * ![Screenshot 2024-06-25 at 1.51.38 PM.png](attachment:7f23abf5-836e-436c-9647-dcde22cac87a.png)
#    * optional: equivalent command line
#    * create
# 3. **cmd**
#    * `hpot` -> check what kind of machines we get
#    * `gcloud --version`
# 4. **configure anaconda**
#    * ![Screenshot 2024-06-25 at 1.58.46 PM.png](attachment:b62d8513-1c2e-4043-88a8-3b405a20e1e0.png)
#    *
